# %%
import tsdb
import pandas as pd

# %%
data = tsdb.load('physionet_2012')
# Out:
# 2025-05-09 19:22:01 [INFO]: You're using dataset physionet_2012, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/physionet_2012
# 2025-05-09 19:22:01 [INFO]: Dataset physionet_2012 has already been downloaded. Processing directly...
# 2025-05-09 19:22:01 [INFO]: Dataset physionet_2012 has already been cached. Loading from cache directly...
# 2025-05-09 19:22:01 [INFO]: Loaded successfully!

# %%
df = pd.DataFrame(data['set-a'])

# %%
df
# Out:
# Parameter  ALP  ALT  AST   Age  Albumin  BUN  Bilirubin  Cholesterol  \
# 0          NaN  NaN  NaN  54.0      NaN  NaN        NaN          NaN
# 1          NaN  NaN  NaN  54.0      NaN  NaN        NaN          NaN
# 2          NaN  NaN  NaN  54.0      NaN  NaN        NaN          NaN
# 3          NaN  NaN  NaN  54.0      NaN  NaN        NaN          NaN
# 4          NaN  NaN  NaN  54.0      NaN  NaN        NaN          NaN
# ..         ...  ...  ...   ...      ...  ...        ...          ...
# 42         NaN  NaN  NaN  78.0      NaN  NaN        NaN          NaN
# 43         NaN  NaN  NaN  78.0      NaN  NaN        NaN          NaN
# 44         NaN  NaN  NaN  78.0      NaN  NaN        NaN          NaN
# 45         NaN  NaN  NaN  78.0      NaN  NaN        NaN          NaN
# 46         NaN  NaN  NaN  78.0      NaN  NaN        NaN          NaN
#
# Parameter  Creatinine  DiasABP  ...  SaO2  SysABP   Temp  Time  TroponinI  \
# ...
